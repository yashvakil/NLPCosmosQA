# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('valid.csv')

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score

# %%
df.columns
# Out:
# Index(['id', 'context', 'question', 'answer0', 'answer1', 'answer2', 'answer3',
#        'label', 'pred_bert', 'logits_bert', 'pred_roberta', 'logits_roberta'],
#       dtype='object')

# %%
y_true = df['label']
y_pred = df['pred']

# %%
acc = accuracy_score(y_true,y_pred)
prec = precision_score(y_true,y_pred,average='micro')
recall = recall_score(y_true,y_pred,average='micro')
f1 = f1_score(y_true,y_pred,average='micro')

# %%
acc
# Out:
# 0.6217755443886097

# %%
df.head(5)
# Out:
#                                                   id  \
# 0  3BFF0DJK8XA7YNK4QYIGCOG1A95STE##3180JW2OT5AF02...
# 1  3BFF0DJK8XA7YNK4QYIGCOG1A95STE##3180JW2OT5AF02...
# 2  3AXFSPQOYQW4GFJD8K4D3JADN54FJ9##352YTHGROWB1DD...
# 3  3AXFSPQOYQW4GFJD8K4D3JADN54FJ9##352YTHGROWB1DD...
# 4  3AXFSPQOYQW4GFJD8K4D3JADN54FJ9##352YTHGROWB1DD...
#
#                                              context  \
# 0  Do i need to go for a legal divorce ? I wanted...
# 1  Do i need to go for a legal divorce ? I wanted...
# 2  I was walking home from the store , when I saw...
# 3  I was walking home from the store , when I saw...
# 4  I was walking home from the store , when I saw...
#
#                                             question  \
# 0          Why is this person asking about divorce ?
# 1          Why is he worried about getting married ?
# 2  What may happen after the young man makes his ...
# 3  What may happen after the young man makes his ...
# ...

# %%
false_data_bert = df[df['label'] != df['pred_bert']]
false_data_bert.head()
# Out:
#                                                    id  \
# 0   3BFF0DJK8XA7YNK4QYIGCOG1A95STE##3180JW2OT5AF02...
# 1   3BFF0DJK8XA7YNK4QYIGCOG1A95STE##3180JW2OT5AF02...
# 9   3FSEU3P2NRYIHT7Z7KDGMZAN0V7RRC##38BQUHLA9XYR9K...
# 10  3FSEU3P2NRYIHT7Z7KDGMZAN0V7RRC##38BQUHLA9XYR9K...
# 14  3O4VWC1GEW49033KOP3B2ALGKVF3J0##37M28K1J0RBC68...
#
#                                               context  \
# 0   Do i need to go for a legal divorce ? I wanted...
# 1   Do i need to go for a legal divorce ? I wanted...
# 9   I watched the first McCain / Obama debate last...
# 10  I watched the first McCain / Obama debate last...
# 14  I spoke with mom a few days before Baby E 's 6...
#
#                                              question  \
# 0           Why is this person asking about divorce ?
# 1           Why is he worried about getting married ?
# 9               How would this person be classified ?
# 10              How would this person be classified ?
# ...

# %%
false_data_bert.to_csv('analysis_data_bert.csv')

# %%
false_data_roberta = df[df['label'] != df['pred_roberta']]

# %%
false_data_roberta.shape
# Out:
# (714, 12)

# %%
false_data_roberta.to_csv('analysis_data_roberta.csv',index=False)

# %% [markdown]
# # lets make a file to compare bert and roberta output

# %% [markdown]
# set a file where bert output goes false but roberta goes right and also cases where bert is right and roberta is wrong and where both goes wrong.

# %%
#case1
df.head(2)
# Out:
#                                                   id  \
# 0  3BFF0DJK8XA7YNK4QYIGCOG1A95STE##3180JW2OT5AF02...
# 1  3BFF0DJK8XA7YNK4QYIGCOG1A95STE##3180JW2OT5AF02...
#
#                                              context  \
# 0  Do i need to go for a legal divorce ? I wanted...
# 1  Do i need to go for a legal divorce ? I wanted...
#
#                                     question  \
# 0  Why is this person asking about divorce ?
# 1  Why is he worried about getting married ?
#
#                                              answer0  \
# 0  If he gets married in the church he wo nt have...
# 1  He was married before and she might come back ...
#
#                                              answer1  \
# 0    He wants to get married to a different person .
# 1  He wants the girl he is going to marry get in ...
#
#                                              answer2  \
# 0  He wants to know if he does nt like this girl ...
# 1     He knows that he will be committing polygamy .
#
# ...

# %%
case1 = df[df['pred_bert'] != df['pred_roberta']]
case1.shape
# Out:
# (1069, 12)

# %%
case1[case1['label']==case1['pred_roberta']]
# Out:
#                                                      id  \
# 1     3BFF0DJK8XA7YNK4QYIGCOG1A95STE##3180JW2OT5AF02...
# 19    31GECDVA9JKW9RBVN87K09SV89N66F##33CID57105RIHD...
# 26    37J05LC5AXH7IV5HHE9NFJ7SBDMDJ0##3CP1TO84PUZFU6...
# 35    3J9UN9O9J56SD03UP0XSSABHAI60JN##38JBBYETQRP4OS...
# 37    3X2LT8FDHWGH7K9P75HMIHNZ29H8WL##3W8CV64QJ3X2AJ...
# ...                                                 ...
# 2955  3TX9T2ZCB9ZWRGACGVHZV1K31OMZWR##33TIN5LC058OWE...
# 2964  3D7VY91L67BJYVCPQD79SJZH5GYBMO##33LK57MYLWKL18...
# 2965  3D7VY91L67BJYVCPQD79SJZH5GYBMO##33LK57MYLWKL18...
# 2979  30U1YOGZGAU0HYO748I17KYF7RGSD2##3QEMNNSB2YXHKK...
# 2981  3CVBMEMMXDUA458OMZFGVC5P509H7S##32UTUBMZ7JB5B2...
#
#                                                 context  \
# 1     Do i need to go for a legal divorce ? I wanted...
# 19    Nine mornings out of ten look just like this i...
# 26    I decided to write about my mom 's life . It '...
# 35    The sort of boys who would while away their ti...
# ...

# %%
import operator

data = df[operator.and_(df['label']!=df['pred_bert'],df['label']!=df['pred_roberta'])]

# %%
data
# Out:
#                                                      id  \
# 0     3BFF0DJK8XA7YNK4QYIGCOG1A95STE##3180JW2OT5AF02...
# 9     3FSEU3P2NRYIHT7Z7KDGMZAN0V7RRC##38BQUHLA9XYR9K...
# 10    3FSEU3P2NRYIHT7Z7KDGMZAN0V7RRC##38BQUHLA9XYR9K...
# 14    3O4VWC1GEW49033KOP3B2ALGKVF3J0##37M28K1J0RBC68...
# 15    3O4VWC1GEW49033KOP3B2ALGKVF3J0##37M28K1J0RBC68...
# ...                                                 ...
# 2956  344M16OZKKTNNG99C5OZ66U2D62ENE##3EJPLAJKEPVGEA...
# 2962  3FHTJGYT8NY6GQI6EHFFI0W1XQFGPS##33FBRBDW6PXBF6...
# 2974  3T6EIBTM9N2DDKY8NWH8OHKBTFAAAQ##3WR9XG3T66QJFD...
# 2975  3T6EIBTM9N2DDKY8NWH8OHKBTFAAAQ##3WR9XG3T66QJFD...
# 2976  3ZZAYRN1I857UKRI3FD7KHU86NCTOA##39OWYR0EPN6CSD...
#
#                                                 context  \
# 0     Do i need to go for a legal divorce ? I wanted...
# 9     I watched the first McCain / Obama debate last...
# 10    I watched the first McCain / Obama debate last...
# 14    I spoke with mom a few days before Baby E 's 6...
# ...

# %%
data.to_csv('bert_roberta_wrong.csv')

# %%
data_same  = data[data['pred_bert']==data['pred_roberta']]
data_same
# Out:
#                                                      id  \
# 9     3FSEU3P2NRYIHT7Z7KDGMZAN0V7RRC##38BQUHLA9XYR9K...
# 10    3FSEU3P2NRYIHT7Z7KDGMZAN0V7RRC##38BQUHLA9XYR9K...
# 14    3O4VWC1GEW49033KOP3B2ALGKVF3J0##37M28K1J0RBC68...
# 15    3O4VWC1GEW49033KOP3B2ALGKVF3J0##37M28K1J0RBC68...
# 17    3TRB893CSJ8HAKE6IVLYIE5GXP4G72##3D3VGR7TA1DTKB...
# ...                                                 ...
# 2882  3D17ECOUOET25MNGY0X5YAPUQAG31P##3CPLWGV3MPXUKF...
# 2935  3SU800BH886PF9JNIXVLEIBA47WQUB##37UEWGM5HWNC5X...
# 2956  344M16OZKKTNNG99C5OZ66U2D62ENE##3EJPLAJKEPVGEA...
# 2962  3FHTJGYT8NY6GQI6EHFFI0W1XQFGPS##33FBRBDW6PXBF6...
# 2974  3T6EIBTM9N2DDKY8NWH8OHKBTFAAAQ##3WR9XG3T66QJFD...
#
#                                                 context  \
# 9     I watched the first McCain / Obama debate last...
# 10    I watched the first McCain / Obama debate last...
# 14    I spoke with mom a few days before Baby E 's 6...
# 15    I spoke with mom a few days before Baby E 's 6...
# ...
